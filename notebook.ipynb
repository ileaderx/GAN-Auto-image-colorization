# %%
import os
os.makedirs('landscape', exist_ok=True) # 40,000 images
os.makedirs('landscape', exist_ok=True)   #  1,000 images
for i, file in enumerate(os.listdir('testSet_resize')):
  if i < 3: # first 1000 will be val
    os.rename('testSet_resize/' + file, 'data' + file)
  else: # others will be val
    os.rename('testSet_resize/' + file, 'data' + file)

# %%
# Make sure the images are there
from IPython.display import Image, display
display(Image(filename='landscape/color/0.jpg'))

# %%
# For plotting
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# For conversion
from skimage.color import lab2rgb, rgb2lab, rgb2gray
from skimage import io
# For everything
import torch
import torch.nn as nn
import torch.nn.functional as F
# For our model
import torchvision.models as models
from torchvision import datasets, transforms
# For utilities
import os, shutil, time

# %%
# Check if GPU is available
use_gpu = torch.cuda.is_available()
print(torch.cuda.is_available())
# Out:
# True

# %%
class ColorizationNet(nn.Module):
  def __init__(self, input_size=128):
    super(ColorizationNet, self).__init__()
    MIDLEVEL_FEATURE_SIZE = 128

    ## First half: ResNet
    resnet = models.resnet18(num_classes=365) 
    # Change first conv layer to accept single-channel (grayscale) input
    resnet.conv1.weight = nn.Parameter(resnet.conv1.weight.sum(dim=1).unsqueeze(1)) 
    # Extract midlevel features from ResNet-gray
    self.midlevel_resnet = nn.Sequential(*list(resnet.children())[0:6])

    ## Second half: Upsampling
    self.upsample = nn.Sequential(     
      nn.Conv2d(MIDLEVEL_FEATURE_SIZE, 128, kernel_size=3, stride=1, padding=1),
      nn.BatchNorm2d(128),
      nn.ReLU(),
      nn.Upsample(scale_factor=2),
      nn.Conv2d(128, 64, kernel_size=3, stride=1, padding=1),
      nn.BatchNorm2d(64),
      nn.ReLU(),
      nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1),
      nn.BatchNorm2d(64),
      nn.ReLU(),
      nn.Upsample(scale_factor=2),
      nn.Conv2d(64, 32, kernel_size=3, stride=1, padding=1),
      nn.BatchNorm2d(32),
      nn.ReLU(),
      nn.Conv2d(32, 2, kernel_size=3, stride=1, padding=1),
      nn.Upsample(scale_factor=2)
    )

  def forward(self, input):

    # Pass input through ResNet-gray to extract features
    midlevel_features = self.midlevel_resnet(input)

    # Upsample to get colors
    output = self.upsample(midlevel_features)
    return output

# %%
model = ColorizationNet()

# %%
criterion = nn.MSELoss()

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=1e-2, weight_decay=0.0)

# %%
class GrayscaleImageFolder(datasets.ImageFolder):
  '''Custom images folder, which converts images to grayscale before loading'''
  def __getitem__(self, index):
    path, target = self.imgs[index]
    img = self.loader(path)
    if self.transform is not None:
      img_original = self.transform(img)
      img_original = np.asarray(img_original)
      img_lab = rgb2lab(img_original)
      img_lab = (img_lab + 128) / 255
      img_ab = img_lab[:, :, 1:3]
      img_ab = torch.from_numpy(img_ab.transpose((2, 0, 1))).float()
      img_original = rgb2gray(img_original)
      img_original = torch.from_numpy(img_original).unsqueeze(0).float()
    if self.target_transform is not None:
      target = self.target_transform(target)
    return img_original, img_ab, target

# %%
# Training
train_transforms = transforms.Compose([transforms.RandomResizedCrop(224), transforms.RandomHorizontalFlip()])
train_imagefolder = GrayscaleImageFolder('landscape', train_transforms)
train_loader = torch.utils.data.DataLoader(train_imagefolder, batch_size=64, shuffle=True)

# Validation 
val_transforms = transforms.Compose([transforms.Resize(256), transforms.CenterCrop(224)])
val_imagefolder = GrayscaleImageFolder('landscape' , val_transforms)
val_loader = torch.utils.data.DataLoader(val_imagefolder, batch_size=64, shuffle=False)

# %%
class AverageMeter(object):
  '''A handy class from the PyTorch ImageNet tutorial''' 
  def __init__(self):
    self.reset()
  def reset(self):
    self.val, self.avg, self.sum, self.count = 0, 0, 0, 0
  def update(self, val, n=1):
    self.val = val
    self.sum += val * n
    self.count += n
    self.avg = self.sum / self.count

def to_rgb(grayscale_input, ab_input, save_path=None, save_name=None):
  '''Show/save rgb image from grayscale and ab channels
     Input save_path in the form {'grayscale': '/path/', 'colorized': '/path/'}'''
  plt.clf() # clear matplotlib 
  color_image = torch.cat((grayscale_input, ab_input), 0).numpy() # combine channels
  color_image = color_image.transpose((1, 2, 0))  # rescale for matplotlib
  color_image[:, :, 0:1] = color_image[:, :, 0:1] * 100
  color_image[:, :, 1:3] = color_image[:, :, 1:3] * 255 - 128   
  color_image = lab2rgb(color_image.astype(np.float64))
  grayscale_input = grayscale_input.squeeze().numpy()
  if save_path is not None and save_name is not None: 
    plt.imsave(arr=grayscale_input, fname='{}{}'.format(save_path['grayscale'], save_name), cmap='gray')
    plt.imsave(arr=color_image, fname='{}{}'.format(save_path['colorized'], save_name))

# %%
def validate(val_loader, model, criterion, save_images, epoch):
  model.eval()

  # Prepare value counters and timers
  batch_time, data_time, losses = AverageMeter(), AverageMeter(), AverageMeter()

  end = time.time()
  already_saved_images = False
  for i, (input_gray, input_ab, target) in enumerate(val_loader):
    data_time.update(time.time() - end)

    # Use GPU
    if use_gpu: input_gray, input_ab, target = input_gray.cuda(), input_ab.cuda(), target.cuda()

    # Run model and record loss
    output_ab = model(input_gray) # throw away class predictions
    loss = criterion(output_ab, input_ab)
    losses.update(loss.item(), input_gray.size(0))

    # Save images to file
    if save_images and not already_saved_images:
      already_saved_images = True
      for j in range(min(len(output_ab), 17)): # save at most 5 images
        save_path = {'grayscale': 'outputs/gray/', 'colorized': 'outputs/color/'}
        save_name = 'img-{}-epoch-{}.jpg'.format(i * val_loader.batch_size + j, epoch)
        to_rgb(input_gray[j].cpu(), ab_input=output_ab[j].detach().cpu(), save_path=save_path, save_name=save_name)

    # Record time to do forward passes and save images
    batch_time.update(time.time() - end)
    end = time.time()

    # Print model accuracy -- in the code below, val refers to both value and validation
    if i % 25 == 0:
      print('Validate: [{0}/{1}]\t'
            'Time {batch_time.val:.3f} ({batch_time.avg:.3f})\t'
            'Loss {loss.val:.4f} ({loss.avg:.4f})\t'.format(
             i, len(val_loader), batch_time=batch_time, loss=losses))

  print('Finished validation.')
  return losses.avg

# %%
def train(train_loader, model, criterion, optimizer, epoch):
  print('Starting training epoch {}'.format(epoch))
  model.train()
  
  # Prepare value counters and timers
  batch_time, data_time, losses = AverageMeter(), AverageMeter(), AverageMeter()

  end = time.time()
  for i, (input_gray, input_ab, target) in enumerate(train_loader):
    
    # Use GPU if available
    if use_gpu: input_gray, input_ab, target = input_gray.cuda(), input_ab.cuda(), target.cuda()

    # Record time to load data (above)
    data_time.update(time.time() - end)

    # Run forward pass
    output_ab = model(input_gray) 
    loss = criterion(output_ab, input_ab) 
    losses.update(loss.item(), input_gray.size(0))

    # Compute gradient and optimize
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    # Record time to do forward and backward passes
    batch_time.update(time.time() - end)
    end = time.time()

    # Print model accuracy -- in the code below, val refers to value, not validation
    if i % 25 == 0:
      print('Epoch: [{0}][{1}/{2}]\t'
            'Time {batch_time.val:.3f} ({batch_time.avg:.3f})\t'
            'Data {data_time.val:.3f} ({data_time.avg:.3f})\t'
            'Loss {loss.val:.4f} ({loss.avg:.4f})\t'.format(
              epoch, i, len(train_loader), batch_time=batch_time,
             data_time=data_time, loss=losses)) 

  print('Finished training epoch {}'.format(epoch))

# %%
if use_gpu: 
  criterion = criterion.cuda()
  model = model.cuda()

# %%
# Make folders and set parameters
os.makedirs('outputs/color', exist_ok=True)
os.makedirs('outputs/gray', exist_ok=True)
os.makedirs('checkpoints', exist_ok=True)
save_images = True
best_losses = 1e9
epochs = 10000

# %%
torch.cuda.empty_cache()

# %%
# Train model
for epoch in range(epochs):
  # Train for one epoch, then validate
  train(train_loader, model, criterion, optimizer, epoch)
  with torch.no_grad():
    losses = validate(val_loader, model, criterion, save_images, epoch)
  # Save checkpoint and replace old best model if current model is better
  if losses < best_losses:
    best_losses = losses
    torch.save(model.state_dict(), 'checkpoints/model-epoch-{}-losses-{:.3f}.pth'.format(epoch+1,losses))
# Out:
# 2.172)	Data 2.022 (2.022)	Loss 0.0009 (0.0009)
# Finished training epoch 9912
# Validate: [0/1]	Time 3.151 (3.151)	Loss 0.0010 (0.0010)
# Finished validation.
# Starting training epoch 9913
# Epoch: [9913][0/1]	Time 2.447 (2.447)	Data 2.273 (2.273)	Loss 0.0009 (0.0009)
# Finished training epoch 9913
# Validate: [0/1]	Time 4.071 (4.071)	Loss 0.0008 (0.0008)
# Finished validation.
# Starting training epoch 9914
# Epoch: [9914][0/1]	Time 2.641 (2.641)	Data 2.476 (2.476)	Loss 0.0008 (0.0008)
# Finished training epoch 9914
# Validate: [0/1]	Time 3.621 (3.621)	Loss 0.0009 (0.0009)
# Finished validation.
# Starting training epoch 9915
# Epoch: [9915][0/1]	Time 2.280 (2.280)	Data 2.099 (2.099)	Loss 0.0009 (0.0009)
# Finished training epoch 9915
# Validate: [0/1]	Time 3.422 (3.422)	Loss 0.0010 (0.0010)
# Finished validation.
# Starting training epoch 9916
# Epoch: [9916][0/1]	Time 2.121 (2.121)	Data 1.961 (1.961)	Loss 0.0008 (0.0008)
# Finished training epoch 9916
# Validate: [0/1]	Time 3.116 (3.116)	Loss 0.0010 (0.0010)
# Finished validation.
# Starting training epoch 9917
# Epoch: [9917][0/1]	Time 2.047 (2.047)	Data 1.897 (1.897)	Loss 0.0008 (0.0008)
# Finished training epoch 9917
# C:\Users\ileaderx\anaconda3\lib\site-packages\skimage\color\colorconv.py:1128: UserWarning: Color data out of range: Z < 0 in 162 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# Validate: [0/1]	Time 3.782 (3.782)	Loss 0.0011 (0.0011)
# Finished validation.
# Starting training epoch 9918
# Epoch: [9918][0/1]	Time 2.547 (2.547)	Data 2.380 (2.380)	Loss 0.0011 (0.0011)
# Finished training epoch 9918
# Validate: [0/1]	Time 3.520 (3.520)	Loss 0.0015 (0.0015)
# Finished validation.
# Starting training epoch 9919
# Epoch: [9919][0/1]	Time 2.432 (2.432)	Data 2.265 (2.265)	Loss 0.0008 (0.0008)
# Finished training epoch 9919
# Validate: [0/1]	Time 3.396 (3.396)	Loss 0.0019 (0.0019)
# Finished validation.
# Starting training epoch 9920
# Epoch: [9920][0/1]	Time 2.204 (2.204)	Data 2.055 (2.055)	Loss 0.0008 (0.0008)
# Finished training epoch 9920
# Validate: [0/1]	Time 3.202 (3.202)	Loss 0.0021 (0.0021)
# Finished validation.
# Starting training epoch 9921
# Epoch: [9921][0/1]	Time 2.017 (2.017)	Data 1.864 (1.864)	Loss 0.0006 (0.0006)
# Finished training epoch 9921
# Validate: [0/1]	Time 3.094 (3.094)	Loss 0.0023 (0.0023)
# Finished validation.
# Starting training epoch 9922
# Epoch: [9922][0/1]	Time 2.244 (2.244)	Data 2.095 (2.095)	Loss 0.0007 (0.0007)
# Finished training epoch 9922
# Validate: [0/1]	Time 3.908 (3.908)	Loss 0.0023 (0.0023)
# Finished validation.
# Starting training epoch 9923
# Epoch: [9923][0/1]	Time 2.574 (2.574)	Data 2.404 (2.404)	Loss 0.0009 (0.0009)
# Finished training epoch 9923
# Validate: [0/1]	Time 3.351 (3.351)	Loss 0.0024 (0.0024)
# Finished validation.
# Starting training epoch 9924
# Epoch: [9924][0/1]	Time 2.364 (2.364)	Data 2.205 (2.205)	Loss 0.0010 (0.0010)
# Finished training epoch 9924
# C:\Users\ileaderx\anaconda3\lib\site-packages\skimage\color\colorconv.py:1128: UserWarning: Color data out of range: Z < 0 in 340 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# Validate: [0/1]	Time 3.085 (3.085)	Loss 0.0018 (0.0018)
# Finished validation.
# Starting training epoch 9925
# Epoch: [9925][0/1]	Time 2.298 (2.298)	Data 2.140 (2.140)	Loss 0.0007 (0.0007)
# Finished training epoch 9925
# C:\Users\ileaderx\anaconda3\lib\site-packages\skimage\color\colorconv.py:1128: UserWarning: Color data out of range: Z < 0 in 556 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# Validate: [0/1]	Time 2.944 (2.944)	Loss 0.0011 (0.0011)
# Finished validation.
# Starting training epoch 9926
# Epoch: [9926][0/1]	Time 1.991 (1.991)	Data 1.839 (1.839)	Loss 0.0007 (0.0007)
# Finished training epoch 9926
# Validate: [0/1]	Time 3.201 (3.201)	Loss 0.0008 (0.0008)
# Finished validation.
# Starting training epoch 9927
# Epoch: [9927][0/1]	Time 2.619 (2.619)	Data 2.463 (2.463)	Loss 0.0008 (0.0008)
# Finished training epoch 9927
# Validate: [0/1]	Time 3.476 (3.476)	Loss 0.0007 (0.0007)
# Finished validation.
# Starting training epoch 9928
# Epoch: [9928][0/1]	Time 2.364 (2.364)	Data 2.169 (2.169)	Loss 0.0008 (0.0008)
# Finished training epoch 9928
# Validate: [0/1]	Time 3.420 (3.420)	Loss 0.0007 (0.0007)
# Finished validation.
# Starting training epoch 9929
# Epoch: [9929][0/1]	Time 2.260 (2.260)	Data 2.089 (2.089)	Loss 0.0010 (0.0010)
# Finished training epoch 9929
# Validate: [0/1]	Time 3.277 (3.277)	Loss 0.0008 (0.0008)
# Finished validation.
# Starting training epoch 9930
# Epoch: [9930][0/1]	Time 1.963 (1.963)	Data 1.809 (1.809)	Loss 0.0007 (0.0007)
# Finished training epoch 9930
# Validate: [0/1]	Time 3.128 (3.128)	Loss 0.0010 (0.0010)
# Finished validation.
# Starting training epoch 9931
# Epoch: [9931][0/1]	Time 2.610 (2.610)	Data 2.426 (2.426)	Loss 0.0007 (0.0007)
# Finished training epoch 9931
# Validate: [0/1]	Time 4.169 (4.169)	Loss 0.0012 (0.0012)
# Finished validation.
# Starting training epoch 9932
# Epoch: [9932][0/1]	Time 2.616 (2.616)	Data 2.451 (2.451)	Loss 0.0008 (0.0008)
# Finished training epoch 9932
# Validate: [0/1]	Time 3.873 (3.873)	Loss 0.0012 (0.0012)
# Finished validation.
# Starting training epoch 9933
# Epoch: [9933][0/1]	Time 2.731 (2.731)	Data 2.569 (2.569)	Loss 0.0007 (0.0007)
# Finished training epoch 9933
# Validate: [0/1]	Time 3.271 (3.271)	Loss 0.0013 (0.0013)
# Finished validation.
# Starting training epoch 9934
# Epoch: [9934][0/1]	Time 2.137 (2.137)	Data 1.985 (1.985)	Loss 0.0007 (0.0007)
# Finished training epoch 9934
# Validate: [0/1]	Time 3.505 (3.505)	Loss 0.0013 (0.0013)
# Finished validation.
# Starting training epoch 9935
# Epoch: [9935][0/1]	Time 2.084 (2.084)	Data 1.930 (1.930)	Loss 0.0007 (0.0007)
# Finished training epoch 9935
# Validate: [0/1]	Time 3.057 (3.057)	Loss 0.0013 (0.0013)
# Finished validation.
# Starting training epoch 9936
# Epoch: [9936][0/1]	Time 2.626 (2.626)	Data 2.432 (2.432)	Loss 0.0007 (0.0007)
# Finished training epoch 9936
# Validate: [0/1]	Time 3.937 (3.937)	Loss 0.0013 (0.0013)
# Finished validation.
# Starting training epoch 9937
# Epoch: [9937][0/1]	Time 2.510 (2.510)	Data 2.315 (2.315)	Loss 0.0009 (0.0009)
# Finished training epoch 9937
# Validate: [0/1]	Time 3.592 (3.592)	Loss 0.0013 (0.0013)
# Finished validation.
# Starting training epoch 9938
# Epoch: [9938][0/1]	Time 2.603 (2.603)	Data 2.439 (2.439)	Loss 0.0008 (0.0008)
# Finished training epoch 9938
# Validate: [0/1]	Time 3.042 (3.042)	Loss 0.0013 (0.0013)
# Finished validation.
# Starting training epoch 9939
# Epoch: [9939][0/1]	Time 2.264 (2.264)	Data 2.114 (2.114)	Loss 0.0010 (0.0010)
# Finished training epoch 9939
# Validate: [0/1]	Time 2.903 (2.903)	Loss 0.0012 (0.0012)
# Finished validation.
# Starting training epoch 9940
# Epoch: [9940][0/1]	Time 2.207 (2.207)	Data 2.053 (2.053)	Loss 0.0008 (0.0008)
# Finished training epoch 9940
# Validate: [0/1]	Time 3.214 (3.214)	Loss 0.0013 (0.0013)
# Finished validation.
# Starting training epoch 9941
# Epoch: [9941][0/1]	Time 2.716 (2.716)	Data 2.530 (2.530)	Loss 0.0007 (0.0007)
# Finished training epoch 9941
# Validate: [0/1]	Time 3.716 (3.716)	Loss 0.0012 (0.0012)
# Finished validation.
# Starting training epoch 9942
# Epoch: [9942][0/1]	Time 2.589 (2.589)	Data 2.438 (2.438)	Loss 0.0008 (0.0008)
# Finished training epoch 9942
# Validate: [0/1]	Time 3.596 (3.596)	Loss 0.0012 (0.0012)
# Finished validation.
# Starting training epoch 9943
# Epoch: [9943][0/1]	Time 2.389 (2.389)	Data 2.201 (2.201)	Loss 0.0008 (0.0008)
# Finished training epoch 9943
# Validate: [0/1]	Time 3.517 (3.517)	Loss 0.0013 (0.0013)
# Finished validation.
# Starting training epoch 9944
# Epoch: [9944][0/1]	Time 2.518 (2.518)	Data 2.321 (2.321)	Loss 0.0007 (0.0007)
# Finished training epoch 9944
# C:\Users\ileaderx\anaconda3\lib\site-packages\skimage\color\colorconv.py:1128: UserWarning: Color data out of range: Z < 0 in 372 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# Validate: [0/1]	Time 4.885 (4.885)	Loss 0.0015 (0.0015)
# Finished validation.
# Starting training epoch 9945
# Epoch: [9945][0/1]	Time 3.384 (3.384)	Data 3.221 (3.221)	Loss 0.0008 (0.0008)
# Finished training epoch 9945
# Validate: [0/1]	Time 6.542 (6.542)	Loss 0.0015 (0.0015)
# Finished validation.
# Starting training epoch 9946
# Epoch: [9946][0/1]	Time 4.487 (4.487)	Data 4.334 (4.334)	Loss 0.0008 (0.0008)
# Finished training epoch 9946
# Validate: [0/1]	Time 4.044 (4.044)	Loss 0.0014 (0.0014)
# Finished validation.
# Starting training epoch 9947
# Epoch: [9947][0/1]	Time 4.038 (4.038)	Data 3.856 (3.856)	Loss 0.0009 (0.0009)
# Finished training epoch 9947
# Validate: [0/1]	Time 4.024 (4.024)	Loss 0.0012 (0.0012)
# Finished validation.
# Starting training epoch 9948
# Epoch: [9948][0/1]	Time 2.360 (2.360)	Data 2.212 (2.212)	Loss 0.0010 (0.0010)
# Finished training epoch 9948
# Validate: [0/1]	Time 3.225 (3.225)	Loss 0.0011 (0.0011)
# Finished validation.
# Starting training epoch 9949
# Epoch: [9949][0/1]	Time 2.431 (2.431)	Data 2.268 (2.268)	Loss 0.0008 (0.0008)
# Finished training epoch 9949
# Validate: [0/1]	Time 3.460 (3.460)	Loss 0.0012 (0.0012)
# Finished validation.
# Starting training epoch 9950
# Epoch: [9950][0/1]	Time 2.726 (2.726)	Data 2.491 (2.491)	Loss 0.0008 (0.0008)
# Finished training epoch 9950
# Validate: [0/1]	Time 3.805 (3.805)	Loss 0.0012 (0.0012)
# Finished validation.
# Starting training epoch 9951
# Epoch: [9951][0/1]	Time 2.472 (2.472)	Data 2.309 (2.309)	Loss 0.0010 (0.0010)
# Finished training epoch 9951
# Validate: [0/1]	Time 3.440 (3.440)	Loss 0.0010 (0.0010)
# Finished validation.
# Starting training epoch 9952
# Epoch: [9952][0/1]	Time 2.109 (2.109)	Data 1.950 (1.950)	Loss 0.0008 (0.0008)
# Finished training epoch 9952
# Validate: [0/1]	Time 3.156 (3.156)	Loss 0.0008 (0.0008)
# Finished validation.
# Starting training epoch 9953
# Epoch: [9953][0/1]	Time 2.108 (2.108)	Data 1.950 (1.950)	Loss 0.0008 (0.0008)
# Finished training epoch 9953
# Validate: [0/1]	Time 3.342 (3.342)	Loss 0.0008 (0.0008)
# Finished validation.
# Starting training epoch 9954
# Epoch: [9954][0/1]	Time 2.599 (2.599)	Data 2.434 (2.434)	Loss 0.0009 (0.0009)
# Finished training epoch 9954
# Validate: [0/1]	Time 3.809 (3.809)	Loss 0.0009 (0.0009)
# Finished validation.
# Starting training epoch 9955
# Epoch: [9955][0/1]	Time 2.509 (2.509)	Data 2.319 (2.319)	Loss 0.0007 (0.0007)
# Finished training epoch 9955
# Validate: [0/1]	Time 3.282 (3.282)	Loss 0.0010 (0.0010)
# Finished validation.
# Starting training epoch 9956
# Epoch: [9956][0/1]	Time 2.293 (2.293)	Data 2.134 (2.134)	Loss 0.0007 (0.0007)
# Finished training epoch 9956
# Validate: [0/1]	Time 3.335 (3.335)	Loss 0.0012 (0.0012)
# Finished validation.
# Starting training epoch 9957
# Epoch: [9957][0/1]	Time 2.147 (2.147)	Data 1.991 (1.991)	Loss 0.0008 (0.0008)
# Finished training epoch 9957
# Validate: [0/1]	Time 3.010 (3.010)	Loss 0.0012 (0.0012)
# Finished validation.
# Starting training epoch 9958
# Epoch: [9958][0/1]	Time 3.299 (3.299)	Data 3.118 (3.118)	Loss 0.0010 (0.0010)
# Finished training epoch 9958
# Validate: [0/1]	Time 3.788 (3.788)	Loss 0.0011 (0.0011)
# Finished validation.
# Starting training epoch 9959
# Epoch: [9959][0/1]	Time 2.999 (2.999)	Data 2.818 (2.818)	Loss 0.0007 (0.0007)
# Finished training epoch 9959
# Validate: [0/1]	Time 3.430 (3.430)	Loss 0.0012 (0.0012)
# Finished validation.
# Starting training epoch 9960
# Epoch: [9960][0/1]	Time 2.596 (2.596)	Data 2.417 (2.417)	Loss 0.0007 (0.0007)
# Finished training epoch 9960
# Validate: [0/1]	Time 3.159 (3.159)	Loss 0.0012 (0.0012)
# Finished validation.
# Starting training epoch 9961
# Epoch: [9961][0/1]	Time 2.120 (2.120)	Data 1.962 (1.962)	Loss 0.0007 (0.0007)
# Finished training epoch 9961
# Validate: [0/1]	Time 3.297 (3.297)	Loss 0.0011 (0.0011)
# Finished validation.
# Starting training epoch 9962
# Epoch: [9962][0/1]	Time 2.077 (2.077)	Data 1.929 (1.929)	Loss 0.0008 (0.0008)
# Finished training epoch 9962
# Validate: [0/1]	Time 2.913 (2.913)	Loss 0.0011 (0.0011)
# Finished validation.
# Starting training epoch 9963
# Epoch: [9963][0/1]	Time 2.563 (2.563)	Data 2.399 (2.399)	Loss 0.0007 (0.0007)
# Finished training epoch 9963
# Validate: [0/1]	Time 3.277 (3.277)	Loss 0.0011 (0.0011)
# Finished validation.
# Starting training epoch 9964
# Epoch: [9964][0/1]	Time 2.445 (2.445)	Data 2.293 (2.293)	Loss 0.0008 (0.0008)
# Finished training epoch 9964
# Validate: [0/1]	Time 3.211 (3.211)	Loss 0.0009 (0.0009)
# Finished validation.
# Starting training epoch 9965
# Epoch: [9965][0/1]	Time 2.303 (2.303)	Data 2.143 (2.143)	Loss 0.0010 (0.0010)
# Finished training epoch 9965
# Validate: [0/1]	Time 3.219 (3.219)	Loss 0.0008 (0.0008)
# Finished validation.
# Starting training epoch 9966
# Epoch: [9966][0/1]	Time 2.204 (2.204)	Data 2.038 (2.038)	Loss 0.0008 (0.0008)
# Finished training epoch 9966
# Validate: [0/1]	Time 3.109 (3.109)	Loss 0.0008 (0.0008)
# Finished validation.
# Starting training epoch 9967
# Epoch: [9967][0/1]	Time 2.077 (2.077)	Data 1.923 (1.923)	Loss 0.0007 (0.0007)
# Finished training epoch 9967
# C:\Users\ileaderx\anaconda3\lib\site-packages\skimage\color\colorconv.py:1128: UserWarning: Color data out of range: Z < 0 in 434 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# Validate: [0/1]	Time 3.283 (3.283)	Loss 0.0010 (0.0010)
# Finished validation.
# Starting training epoch 9968
# Epoch: [9968][0/1]	Time 2.960 (2.960)	Data 2.786 (2.786)	Loss 0.0007 (0.0007)
# Finished training epoch 9968
# C:\Users\ileaderx\anaconda3\lib\site-packages\skimage\color\colorconv.py:1128: UserWarning: Color data out of range: Z < 0 in 674 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# Validate: [0/1]	Time 3.853 (3.853)	Loss 0.0012 (0.0012)
# Finished validation.
# Starting training epoch 9969
# Epoch: [9969][0/1]	Time 2.583 (2.583)	Data 2.420 (2.420)	Loss 0.0007 (0.0007)
# Finished training epoch 9969
# Validate: [0/1]	Time 3.223 (3.223)	Loss 0.0013 (0.0013)
# Finished validation.
# Starting training epoch 9970
# Epoch: [9970][0/1]	Time 2.217 (2.217)	Data 2.058 (2.058)	Loss 0.0007 (0.0007)
# Finished training epoch 9970
# Validate: [0/1]	Time 2.889 (2.889)	Loss 0.0012 (0.0012)
# Finished validation.
# Starting training epoch 9971
# Epoch: [9971][0/1]	Time 2.077 (2.077)	Data 1.921 (1.921)	Loss 0.0008 (0.0008)
# Finished training epoch 9971
# Validate: [0/1]	Time 2.848 (2.848)	Loss 0.0012 (0.0012)
# Finished validation.
# Starting training epoch 9972
# Epoch: [9972][0/1]	Time 2.437 (2.437)	Data 2.274 (2.274)	Loss 0.0007 (0.0007)
# Finished training epoch 9972
# Validate: [0/1]	Time 4.027 (4.027)	Loss 0.0012 (0.0012)
# Finished validation.
# Starting training epoch 9973
# Epoch: [9973][0/1]	Time 2.818 (2.818)	Data 2.652 (2.652)	Loss 0.0007 (0.0007)
# Finished training epoch 9973
# Validate: [0/1]	Time 3.478 (3.478)	Loss 0.0012 (0.0012)
# Finished validation.
# Starting training epoch 9974
# Epoch: [9974][0/1]	Time 2.363 (2.363)	Data 2.198 (2.198)	Loss 0.0007 (0.0007)
# Finished training epoch 9974
# Validate: [0/1]	Time 3.595 (3.595)	Loss 0.0011 (0.0011)
# Finished validation.
# Starting training epoch 9975
# Epoch: [9975][0/1]	Time 2.238 (2.238)	Data 2.055 (2.055)	Loss 0.0009 (0.0009)
# Finished training epoch 9975
# Validate: [0/1]	Time 3.146 (3.146)	Loss 0.0010 (0.0010)
# Finished validation.
# Starting training epoch 9976
# Epoch: [9976][0/1]	Time 1.958 (1.958)	Data 1.800 (1.800)	Loss 0.0007 (0.0007)
# Finished training epoch 9976
# Validate: [0/1]	Time 3.468 (3.468)	Loss 0.0009 (0.0009)
# Finished validation.
# Starting training epoch 9977
# Epoch: [9977][0/1]	Time 2.834 (2.834)	Data 2.661 (2.661)	Loss 0.0007 (0.0007)
# Finished training epoch 9977
# Validate: [0/1]	Time 3.507 (3.507)	Loss 0.0008 (0.0008)
# Finished validation.
# Starting training epoch 9978
# Epoch: [9978][0/1]	Time 2.708 (2.708)	Data 2.547 (2.547)	Loss 0.0008 (0.0008)
# Finished training epoch 9978
# Validate: [0/1]	Time 3.334 (3.334)	Loss 0.0007 (0.0007)
# Finished validation.
# Starting training epoch 9979
# Epoch: [9979][0/1]	Time 2.272 (2.272)	Data 2.117 (2.117)	Loss 0.0009 (0.0009)
# Finished training epoch 9979
# Validate: [0/1]	Time 3.052 (3.052)	Loss 0.0007 (0.0007)
# Finished validation.
# Starting training epoch 9980
# Epoch: [9980][0/1]	Time 2.052 (2.052)	Data 1.896 (1.896)	Loss 0.0008 (0.0008)
# Finished training epoch 9980
# Validate: [0/1]	Time 3.251 (3.251)	Loss 0.0007 (0.0007)
# Finished validation.
# Starting training epoch 9981
# Epoch: [9981][0/1]	Time 2.334 (2.334)	Data 2.176 (2.176)	Loss 0.0007 (0.0007)
# Finished training epoch 9981
# Validate: [0/1]	Time 3.616 (3.616)	Loss 0.0008 (0.0008)
# Finished validation.
# Starting training epoch 9982
# Epoch: [9982][0/1]	Time 2.702 (2.702)	Data 2.455 (2.455)	Loss 0.0007 (0.0007)
# Finished training epoch 9982
# Validate: [0/1]	Time 3.890 (3.890)	Loss 0.0008 (0.0008)
# Finished validation.
# Starting training epoch 9983
# Epoch: [9983][0/1]	Time 2.403 (2.403)	Data 2.243 (2.243)	Loss 0.0007 (0.0007)
# Finished training epoch 9983
# Validate: [0/1]	Time 3.615 (3.615)	Loss 0.0008 (0.0008)
# Finished validation.
# Starting training epoch 9984
# Epoch: [9984][0/1]	Time 1.904 (1.904)	Data 1.741 (1.741)	Loss 0.0007 (0.0007)
# Finished training epoch 9984
# Validate: [0/1]	Time 3.343 (3.343)	Loss 0.0008 (0.0008)
# Finished validation.
# Starting training epoch 9985
# Epoch: [9985][0/1]	Time 1.980 (1.980)	Data 1.827 (1.827)	Loss 0.0009 (0.0009)
# Finished training epoch 9985
# Validate: [0/1]	Time 3.031 (3.031)	Loss 0.0007 (0.0007)
# Finished validation.
# Starting training epoch 9986
# Epoch: [9986][0/1]	Time 2.547 (2.547)	Data 2.383 (2.383)	Loss 0.0007 (0.0007)
# Finished training epoch 9986
# Validate: [0/1]	Time 3.752 (3.752)	Loss 0.0007 (0.0007)
# Finished validation.
# Starting training epoch 9987
# Epoch: [9987][0/1]	Time 2.496 (2.496)	Data 2.325 (2.325)	Loss 0.0009 (0.0009)
# Finished training epoch 9987
# Validate: [0/1]	Time 3.453 (3.453)	Loss 0.0007 (0.0007)
# Finished validation.
# Starting training epoch 9988
# Epoch: [9988][0/1]	Time 2.380 (2.380)	Data 2.222 (2.222)	Loss 0.0009 (0.0009)
# Finished training epoch 9988
# Validate: [0/1]	Time 3.059 (3.059)	Loss 0.0007 (0.0007)
# Finished validation.
# Starting training epoch 9989
# Epoch: [9989][0/1]	Time 2.224 (2.224)	Data 2.066 (2.066)	Loss 0.0008 (0.0008)
# Finished training epoch 9989
# Validate: [0/1]	Time 2.817 (2.817)	Loss 0.0007 (0.0007)
# Finished validation.
# Starting training epoch 9990
# Epoch: [9990][0/1]	Time 2.091 (2.091)	Data 1.931 (1.931)	Loss 0.0010 (0.0010)
# Finished training epoch 9990
# Validate: [0/1]	Time 2.980 (2.980)	Loss 0.0007 (0.0007)
# Finished validation.
# Starting training epoch 9991
# Epoch: [9991][0/1]	Time 2.627 (2.627)	Data 2.465 (2.465)	Loss 0.0009 (0.0009)
# Finished training epoch 9991
# Validate: [0/1]	Time 3.306 (3.306)	Loss 0.0008 (0.0008)
# Finished validation.
# Starting training epoch 9992
# Epoch: [9992][0/1]	Time 2.493 (2.493)	Data 2.301 (2.301)	Loss 0.0008 (0.0008)
# Finished training epoch 9992
# Validate: [0/1]	Time 3.494 (3.494)	Loss 0.0008 (0.0008)
# Finished validation.
# Starting training epoch 9993
# Epoch: [9993][0/1]	Time 2.236 (2.236)	Data 2.059 (2.059)	Loss 0.0008 (0.0008)
# Finished training epoch 9993
# Validate: [0/1]	Time 3.070 (3.070)	Loss 0.0008 (0.0008)
# Finished validation.
# Starting training epoch 9994
# Epoch: [9994][0/1]	Time 2.007 (2.007)	Data 1.856 (1.856)	Loss 0.0009 (0.0009)
# Finished training epoch 9994
# Validate: [0/1]	Time 3.006 (3.006)	Loss 0.0008 (0.0008)
# Finished validation.
# Starting training epoch 9995
# Epoch: [9995][0/1]	Time 2.059 (2.059)	Data 1.895 (1.895)	Loss 0.0007 (0.0007)
# Finished training epoch 9995
# Validate: [0/1]	Time 3.374 (3.374)	Loss 0.0008 (0.0008)
# Finished validation.
# Starting training epoch 9996
# Epoch: [9996][0/1]	Time 2.480 (2.480)	Data 2.318 (2.318)	Loss 0.0008 (0.0008)
# Finished training epoch 9996
# Validate: [0/1]	Time 3.663 (3.663)	Loss 0.0008 (0.0008)
# Finished validation.
# Starting training epoch 9997
# Epoch: [9997][0/1]	Time 2.300 (2.300)	Data 2.109 (2.109)	Loss 0.0007 (0.0007)
# Finished training epoch 9997
# Validate: [0/1]	Time 3.431 (3.431)	Loss 0.0007 (0.0007)
# Finished validation.
# Starting training epoch 9998
# Epoch: [9998][0/1]	Time 2.387 (2.387)	Data 2.237 (2.237)	Loss 0.0008 (0.0008)
# Finished training epoch 9998
# Validate: [0/1]	Time 2.971 (2.971)	Loss 0.0007 (0.0007)
# Finished validation.
# Starting training epoch 9999
# Epoch: [9999][0/1]	Time 2.123 (2.123)	Data 1.963 (1.963)	Loss 0.0007 (0.0007)
# Finished training epoch 9999
# Validate: [0/1]	Time 2.811 (2.811)	Loss 0.0007 (0.0007)
# Finished validation.

# %%
# Show images 
import matplotlib.image as mpimg
image_pairs = [('outputs/color/img-2-epoch-0.jpg', 'outputs/gray/img-2-epoch-0.jpg'),
               ('outputs/color/img-7-epoch-0.jpg', 'outputs/gray/img-7-epoch-0.jpg')]
for c, g in image_pairs:
  color = mpimg.imread(c)
  gray  = mpimg.imread(g)
  f, axarr = plt.subplots(1, 2)
  f.set_size_inches(15, 15)
  axarr[0].imshow(gray, cmap='gray')
  axarr[1].imshow(color)
  axarr[0].axis('off'), axarr[1].axis('off')
  plt.show()
